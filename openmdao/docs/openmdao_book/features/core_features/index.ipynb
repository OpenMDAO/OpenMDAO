# %% [markdown]
# # Core Features
#
# - [Working with Components](working_with_components/index)
# - [Working with Groups](working_with_groups/index)
# - [Options](options/index)
# - [Working with Derivatives](working_with_derivatives/index)
# - [Adding design variables, constraints, and objectives](adding_desvars_cons_objs/index)
# - [Running Your Models](running_your_models/index)
# - [Controlling Solver Behavior](controlling_solver_behavior/index)
